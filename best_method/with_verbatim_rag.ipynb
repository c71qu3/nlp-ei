# %% [markdown]
# # Summarization with Verbatim RAG
#
# ### Implementation Description
#
# | Step | Description | Rationale |
# |------|-------------|-----------|
# | Process source document | Break paper into sentences. Encode the full document together, and each sentence independently. |  |
# | Select relevant sentences | Calculate **BM25** similarity score between sentences and full document. | This was the most reliable method for selecting sentences from the baseline results. |
# |  |  |  |
# |  |  |  |
# |  |  |  |
#
# ### Required Modules

# %%
from verbatim_rag.schema import DocumentSchema
from verbatim_rag.chunker_providers import MarkdownChunkerProvider
from verbatim_rag.embedding_providers import SentenceTransformersProvider
from verbatim_rag.vector_stores import LocalMilvusStore
from verbatim_rag import VerbatimIndex, VerbatimRAG
from verbatim_rag.core import LLMClient

# %% [markdown]
# ### Constant Variables

# %%
ARXIV_URL = "https://arxiv.org/pdf/"
DOCUMENT_ID = [
    '2511.21398v1',
    '2511.21444v1',
    '2511.21460v1',
    '2511.21471v1',
    '2511.21522v1',
    '2511.21569v1',
    '2511.21570v1',
    '2511.21591v1',
    '2511.21636v1',
    '2511.21678v1',
]

# %% [markdown]
# ### Process Source Document

# %%
LOAD_PAPERS = True


if LOAD_PAPERS:
    papers = [
        DocumentSchema.from_url(url=ARXIV_URL + document_id)
        for document_id in DOCUMENT_ID
    ]
else:
    print("Papers already loaded!")
# Out:
# 2026-01-04 20:15:12,585 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2026-01-04 20:15:12,663 - INFO - Going to convert document batch...
# 2026-01-04 20:15:12,664 - INFO - Initializing pipeline for StandardPdfPipeline with options hash e15bc6f248154cc62f8db15ef18a8ab7
# 2026-01-04 20:15:12,678 - INFO - Loading plugin 'docling_defaults'
# 2026-01-04 20:15:12,681 - INFO - Registered picture descriptions: ['vlm', 'api']
# 2026-01-04 20:15:12,695 - INFO - Loading plugin 'docling_defaults'
# 2026-01-04 20:15:12,700 - INFO - Registered ocr engines: ['auto', 'easyocr', 'ocrmac', 'rapidocr', 'tesserocr', 'tesseract']
# 2026-01-04 20:15:12,701 - INFO - rapidocr cannot be used because onnxruntime is not installed.
# 2026-01-04 20:15:12,702 - INFO - easyocr cannot be used because it is not installed.
# 2026-01-04 20:15:12,979 - INFO - Accelerator device: 'cpu'
# [INFO] 2026-01-04 20:15:12,993 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:15:12,997 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:15:13,013 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-04 20:15:13,014 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-04 20:15:13,186 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:15:13,187 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:15:13,189 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-04 20:15:13,190 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-04 20:15:13,252 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:15:13,253 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:15:13,278 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-04 20:15:13,279 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# 2026-01-04 20:15:13,455 - INFO - Auto OCR model selected rapidocr with torch.
# 2026-01-04 20:15:13,468 - INFO - Loading plugin 'docling_defaults'
# 2026-01-04 20:15:13,471 - INFO - Registered layout engines: ['docling_layout_default', 'docling_experimental_table_crops_layout']
# 2026-01-04 20:15:13,476 - INFO - Accelerator device: 'cpu'
# 2026-01-04 20:15:14,924 - INFO - Loading plugin 'docling_defaults'
# 2026-01-04 20:15:14,926 - INFO - Registered table structure engines: ['docling_tableformer']
# 2026-01-04 20:15:15,221 - INFO - Accelerator device: 'cpu'
# 2026-01-04 20:15:15,932 - INFO - Processing document 2511.21398v1.pdf
# 2026-01-04 20:16:24,303 - INFO - Finished converting document 2511.21398v1.pdf in 73.94 sec.
# 2026-01-04 20:16:25,476 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2026-01-04 20:16:25,482 - INFO - Going to convert document batch...
# 2026-01-04 20:16:25,483 - INFO - Initializing pipeline for StandardPdfPipeline with options hash e15bc6f248154cc62f8db15ef18a8ab7
# 2026-01-04 20:16:25,484 - INFO - rapidocr cannot be used because onnxruntime is not installed.
# 2026-01-04 20:16:25,484 - INFO - easyocr cannot be used because it is not installed.
# 2026-01-04 20:16:25,484 - INFO - Accelerator device: 'cpu'
# [INFO] 2026-01-04 20:16:25,499 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:16:25,499 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:16:25,517 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-04 20:16:25,518 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-04 20:16:25,653 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:16:25,654 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:16:25,658 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-04 20:16:25,659 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-04 20:16:25,720 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:16:25,721 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:16:25,743 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-04 20:16:25,744 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# 2026-01-04 20:16:25,893 - INFO - Auto OCR model selected rapidocr with torch.
# 2026-01-04 20:16:25,894 - INFO - Accelerator device: 'cpu'
# 2026-01-04 20:16:26,408 - INFO - Accelerator device: 'cpu'
# 2026-01-04 20:16:26,633 - INFO - Processing document 2511.21444v1.pdf
# 2026-01-04 20:16:55,730 - INFO - Finished converting document 2511.21444v1.pdf in 31.34 sec.
# 2026-01-04 20:16:56,424 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2026-01-04 20:16:56,428 - INFO - Going to convert document batch...
# 2026-01-04 20:16:56,428 - INFO - Initializing pipeline for StandardPdfPipeline with options hash e15bc6f248154cc62f8db15ef18a8ab7
# 2026-01-04 20:16:56,429 - INFO - rapidocr cannot be used because onnxruntime is not installed.
# 2026-01-04 20:16:56,429 - INFO - easyocr cannot be used because it is not installed.
# 2026-01-04 20:16:56,430 - INFO - Accelerator device: 'cpu'
# [INFO] 2026-01-04 20:16:56,444 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:16:56,444 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:16:56,453 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-04 20:16:56,454 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-04 20:16:56,580 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:16:56,581 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:16:56,582 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-04 20:16:56,583 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-04 20:16:56,643 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:16:56,644 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:16:56,661 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-04 20:16:56,662 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# 2026-01-04 20:16:56,810 - INFO - Auto OCR model selected rapidocr with torch.
# 2026-01-04 20:16:56,811 - INFO - Accelerator device: 'cpu'
# 2026-01-04 20:16:57,534 - INFO - Accelerator device: 'cpu'
# 2026-01-04 20:16:57,778 - INFO - Processing document 2511.21460v1.pdf
# 2026-01-04 20:17:12,520 - WARNING - RapidOCR returned empty result!
# [WARNING] 2026-01-04 20:17:14,036 [RapidOCR] main.py:125: The text detection result is empty
# 2026-01-04 20:17:14,037 - WARNING - RapidOCR returned empty result!
# 2026-01-04 20:17:33,370 - INFO - Finished converting document 2511.21460v1.pdf in 37.60 sec.
# 2026-01-04 20:17:34,803 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2026-01-04 20:17:34,808 - INFO - Going to convert document batch...
# 2026-01-04 20:17:34,809 - INFO - Initializing pipeline for StandardPdfPipeline with options hash e15bc6f248154cc62f8db15ef18a8ab7
# 2026-01-04 20:17:34,810 - INFO - rapidocr cannot be used because onnxruntime is not installed.
# 2026-01-04 20:17:34,810 - INFO - easyocr cannot be used because it is not installed.
# 2026-01-04 20:17:34,811 - INFO - Accelerator device: 'cpu'
# [INFO] 2026-01-04 20:17:34,826 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:17:34,826 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:17:34,836 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-04 20:17:34,836 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-04 20:17:34,970 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:17:34,971 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:17:34,972 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-04 20:17:34,972 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-04 20:17:35,029 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:17:35,030 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:17:35,045 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-04 20:17:35,046 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# 2026-01-04 20:17:35,204 - INFO - Auto OCR model selected rapidocr with torch.
# 2026-01-04 20:17:35,205 - INFO - Accelerator device: 'cpu'
# 2026-01-04 20:17:35,749 - INFO - Accelerator device: 'cpu'
# 2026-01-04 20:17:35,988 - INFO - Processing document 2511.21471v1.pdf
# 2026-01-04 20:17:38,473 - WARNING - RapidOCR returned empty result!
# 2026-01-04 20:17:39,086 - WARNING - RapidOCR returned empty result!
# 2026-01-04 20:17:43,785 - WARNING - RapidOCR returned empty result!
# 2026-01-04 20:17:46,610 - WARNING - RapidOCR returned empty result!
# 2026-01-04 20:17:46,891 - WARNING - RapidOCR returned empty result!
# 2026-01-04 20:18:01,352 - WARNING - RapidOCR returned empty result!
# 2026-01-04 20:18:28,422 - INFO - Finished converting document 2511.21471v1.pdf in 54.97 sec.
# 2026-01-04 20:18:29,351 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2026-01-04 20:18:29,354 - INFO - Going to convert document batch...
# 2026-01-04 20:18:29,355 - INFO - Initializing pipeline for StandardPdfPipeline with options hash e15bc6f248154cc62f8db15ef18a8ab7
# 2026-01-04 20:18:29,356 - INFO - rapidocr cannot be used because onnxruntime is not installed.
# 2026-01-04 20:18:29,356 - INFO - easyocr cannot be used because it is not installed.
# 2026-01-04 20:18:29,357 - INFO - Accelerator device: 'cpu'
# [INFO] 2026-01-04 20:18:29,371 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:18:29,371 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:18:29,381 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-04 20:18:29,382 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-04 20:18:29,511 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:18:29,511 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:18:29,513 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-04 20:18:29,513 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-04 20:18:29,571 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:18:29,571 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:18:29,587 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-04 20:18:29,588 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# 2026-01-04 20:18:29,739 - INFO - Auto OCR model selected rapidocr with torch.
# 2026-01-04 20:18:29,740 - INFO - Accelerator device: 'cpu'
# 2026-01-04 20:18:30,282 - INFO - Accelerator device: 'cpu'
# 2026-01-04 20:18:30,525 - INFO - Processing document 2511.21522v1.pdf
# 2026-01-04 20:18:59,834 - INFO - Finished converting document 2511.21522v1.pdf in 31.34 sec.
# 2026-01-04 20:19:01,021 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2026-01-04 20:19:01,031 - INFO - Going to convert document batch...
# 2026-01-04 20:19:01,032 - INFO - Initializing pipeline for StandardPdfPipeline with options hash e15bc6f248154cc62f8db15ef18a8ab7
# 2026-01-04 20:19:01,033 - INFO - rapidocr cannot be used because onnxruntime is not installed.
# 2026-01-04 20:19:01,033 - INFO - easyocr cannot be used because it is not installed.
# 2026-01-04 20:19:01,033 - INFO - Accelerator device: 'cpu'
# [INFO] 2026-01-04 20:19:01,047 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:19:01,048 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:19:01,059 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-04 20:19:01,060 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-04 20:19:01,187 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:19:01,187 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:19:01,188 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-04 20:19:01,189 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-04 20:19:01,247 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:19:01,248 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:19:01,265 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-04 20:19:01,266 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# 2026-01-04 20:19:01,426 - INFO - Auto OCR model selected rapidocr with torch.
# 2026-01-04 20:19:01,427 - INFO - Accelerator device: 'cpu'
# 2026-01-04 20:19:01,952 - INFO - Accelerator device: 'cpu'
# 2026-01-04 20:19:02,197 - INFO - Processing document 2511.21569v1.pdf
# 2026-01-04 20:20:16,143 - INFO - Finished converting document 2511.21569v1.pdf in 76.20 sec.
# 2026-01-04 20:20:16,828 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2026-01-04 20:20:16,831 - INFO - Going to convert document batch...
# 2026-01-04 20:20:16,831 - INFO - Initializing pipeline for StandardPdfPipeline with options hash e15bc6f248154cc62f8db15ef18a8ab7
# 2026-01-04 20:20:16,832 - INFO - rapidocr cannot be used because onnxruntime is not installed.
# 2026-01-04 20:20:16,833 - INFO - easyocr cannot be used because it is not installed.
# 2026-01-04 20:20:16,834 - INFO - Accelerator device: 'cpu'
# [INFO] 2026-01-04 20:20:16,846 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:20:16,847 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:20:16,856 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-04 20:20:16,856 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-04 20:20:16,988 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:20:16,989 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:20:16,990 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-04 20:20:16,990 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-04 20:20:17,048 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:20:17,049 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:20:17,067 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-04 20:20:17,067 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# 2026-01-04 20:20:17,222 - INFO - Auto OCR model selected rapidocr with torch.
# 2026-01-04 20:20:17,223 - INFO - Accelerator device: 'cpu'
# 2026-01-04 20:20:17,786 - INFO - Accelerator device: 'cpu'
# 2026-01-04 20:20:18,022 - INFO - Processing document 2511.21570v1.pdf
# 2026-01-04 20:20:31,656 - INFO - Finished converting document 2511.21570v1.pdf in 15.43 sec.
# 2026-01-04 20:20:32,568 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2026-01-04 20:20:32,571 - INFO - Going to convert document batch...
# 2026-01-04 20:20:32,572 - INFO - Initializing pipeline for StandardPdfPipeline with options hash e15bc6f248154cc62f8db15ef18a8ab7
# 2026-01-04 20:20:32,573 - INFO - rapidocr cannot be used because onnxruntime is not installed.
# 2026-01-04 20:20:32,574 - INFO - easyocr cannot be used because it is not installed.
# 2026-01-04 20:20:32,574 - INFO - Accelerator device: 'cpu'
# [INFO] 2026-01-04 20:20:32,588 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:20:32,589 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:20:32,599 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-04 20:20:32,599 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-04 20:20:32,727 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:20:32,728 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:20:32,729 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-04 20:20:32,729 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-04 20:20:32,785 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:20:32,786 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:20:32,802 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-04 20:20:32,802 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# 2026-01-04 20:20:32,953 - INFO - Auto OCR model selected rapidocr with torch.
# 2026-01-04 20:20:32,954 - INFO - Accelerator device: 'cpu'
# 2026-01-04 20:20:33,496 - INFO - Accelerator device: 'cpu'
# 2026-01-04 20:20:33,730 - INFO - Processing document 2511.21591v1.pdf
# 2026-01-04 20:21:31,169 - INFO - Finished converting document 2511.21591v1.pdf in 59.48 sec.
# 2026-01-04 20:21:32,484 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2026-01-04 20:21:32,488 - INFO - Going to convert document batch...
# 2026-01-04 20:21:32,489 - INFO - Initializing pipeline for StandardPdfPipeline with options hash e15bc6f248154cc62f8db15ef18a8ab7
# 2026-01-04 20:21:32,489 - INFO - rapidocr cannot be used because onnxruntime is not installed.
# 2026-01-04 20:21:32,490 - INFO - easyocr cannot be used because it is not installed.
# 2026-01-04 20:21:32,490 - INFO - Accelerator device: 'cpu'
# [INFO] 2026-01-04 20:21:32,502 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:21:32,503 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:21:32,512 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-04 20:21:32,513 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-04 20:21:32,644 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:21:32,645 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:21:32,646 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-04 20:21:32,646 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-04 20:21:32,712 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:21:32,712 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:21:32,728 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-04 20:21:32,729 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# 2026-01-04 20:21:32,884 - INFO - Auto OCR model selected rapidocr with torch.
# 2026-01-04 20:21:32,884 - INFO - Accelerator device: 'cpu'
# 2026-01-04 20:21:33,403 - INFO - Accelerator device: 'cpu'
# 2026-01-04 20:21:33,654 - INFO - Processing document 2511.21636v1.pdf
# 2026-01-04 20:22:09,144 - INFO - Finished converting document 2511.21636v1.pdf in 37.90 sec.
# 2026-01-04 20:22:10,485 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2026-01-04 20:22:10,492 - INFO - Going to convert document batch...
# 2026-01-04 20:22:10,492 - INFO - Initializing pipeline for StandardPdfPipeline with options hash e15bc6f248154cc62f8db15ef18a8ab7
# 2026-01-04 20:22:10,493 - INFO - rapidocr cannot be used because onnxruntime is not installed.
# 2026-01-04 20:22:10,494 - INFO - easyocr cannot be used because it is not installed.
# 2026-01-04 20:22:10,494 - INFO - Accelerator device: 'cpu'
# [INFO] 2026-01-04 20:22:10,507 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:22:10,508 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:22:10,517 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-04 20:22:10,517 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_det_infer.pth
# [INFO] 2026-01-04 20:22:10,653 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:22:10,653 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:22:10,655 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-04 20:22:10,655 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2026-01-04 20:22:10,726 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-01-04 20:22:10,727 [RapidOCR] device_config.py:50: Using CPU device
# [INFO] 2026-01-04 20:22:10,743 [RapidOCR] download_file.py:60: File exists and is valid: /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# [INFO] 2026-01-04 20:22:10,744 [RapidOCR] main.py:50: Using /var/home/shared/TU Wien/Natural Language Processing/project/.venv/lib/python3.13/site-packages/rapidocr/models/ch_PP-OCRv4_rec_infer.pth
# 2026-01-04 20:22:10,911 - INFO - Auto OCR model selected rapidocr with torch.
# 2026-01-04 20:22:10,911 - INFO - Accelerator device: 'cpu'
# 2026-01-04 20:22:11,404 - INFO - Accelerator device: 'cpu'
# 2026-01-04 20:22:11,660 - INFO - Processing document 2511.21678v1.pdf
# 2026-01-04 20:22:54,666 - INFO - Finished converting document 2511.21678v1.pdf in 45.46 sec.

# %%
chunker = MarkdownChunkerProvider(
    min_chunk_size=500,
    max_chunk_size=5000,
)

dense_provider = SentenceTransformersProvider(
    model_name="ibm-granite/granite-embedding-english-r2",
    device='cpu',
)
vector_store = LocalMilvusStore(
    db_path="./rag_test.db",
    collection_name='rag_test',
    dense_dim=dense_provider.get_dimension(),
    enable_dense=True,
    enable_sparse=False,
    nlist=16384,
)
index = VerbatimIndex(
        vector_store=vector_store,
        dense_provider=dense_provider,
        chunker_provider=chunker,
    )

index.add_documents([papers[0]])
# Out:
# 2026-01-04 20:23:07,016 - INFO - PyTorch version 2.9.1 available.
# 2026-01-04 20:23:07,422 - INFO - Load pretrained SentenceTransformer: ibm-granite/granite-embedding-english-r2
# 2026-01-04 20:23:13,337 - INFO - Loaded SentenceTransformers model: ibm-granite/granite-embedding-english-r2
# /home/shared/TU Wien/Natural Language Processing/project/.venv/lib64/python3.13/site-packages/milvus_lite/__init__.py:15: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution
# 2026-01-04 20:23:14,032 - INFO - Connected to Milvus Lite: ./rag_test.db
# Batches: 100%|██████████| 2/2 [01:40<00:00, 50.38s/it]]
# 2026-01-04 20:24:54,914 - INFO - Added 51 vectors to Milvus
# 2026-01-04 20:24:54,943 - INFO - Added 1 documents to Milvus
# Adding documents: 100%|██████████| 1/1 [01:40<00:00, 100.91s/it]

# %%
llm_client = LLMClient(model="gpt-4.1", temperature=1.0)

rag = VerbatimRAG(index, llm_client=llm_client)

response = rag.query("Build a summary of the paper 'Prune4Web: DOM Tree Pruning Programming for Web Agent'.")

print(response.answer)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 15.73it/s]
# Extracting relevant spans...
# Extracting spans (batch mode)...
# 2026-01-04 20:37:54,986 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Warning: Span not found verbatim in document: 'We introduce Prune4Web , a novel paradigm that transforms DOM processing from LLM-based filtering to...'
# Warning: Span not found verbatim in document: 'We introduce Prune4Web , a novel paradigm that transforms DOM processing from LLM-based filtering to...'
# Warning: Span not found verbatim in document: 'Step 1: Initial Rule-based Filtering. The process begins with a rule-based preliminary filtering of ...'
# Warning: Span not found verbatim in document: 'Step 1: Initial Rule-based Filtering. The process begins with a rule-based preliminary filtering of ...'
# Warning: Span not found verbatim in document: 'To this end, we propose a Prune4Web pipeline through a novel paradigm: DOM Tree Pruning Programming....'
# Processing spans...
# Generating response...
# 2026-01-04 20:37:56,919 - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Here is a concise summary of the paper based on the provided verbatim facts:
#
# 1. **Technical Core:** [1] DOM Tree Pruning Programming is the technical core of Prune4Web. It offloads the heavy task of element filtering from the LLM itself to a lightweight, dynamically generated program.
# 2. **Scoring Function Generation:** [2] Step 2: Scoring Function Generation. The core task of the Programmatic Element Filter is to generate a Python scoring function f score t for the current step. We design a heuristic-based Scoring Function Template, where the LLM only needs to generate key parameters for this template. This approach significantly improves the stability and controllability of the generated code while maintaining flexibility. Algorithm 1 shows the pseudo-code of the template. The template mimics human intuition when searching for elements using keywords. It assumes that a target element contains identifiable textual features within the HTML. The template performs tiered, weighted matching across different attributes: Tier 1 includes visible 'text'; Tier 2 includes non-visible but high-semantic attributes like 'aria-label' and 'placeholder'; and Tier 3 includes other attributes like 'class' or 'id' that may contain semantic cues. The template also integrates multiple matching types (e.g., exact, substring, fuzzy) and assigns weights based on match quality. With this design, the Programmatic Element Filter simply generates a set of keywords and their corresponding base weights based on the low-level sub-task S t , enabling multi-faceted relevance scoring for each element.
# 3. **Pruning Execution & Output Formatting:** [3] Step 3: Pruning Execution and Output Formatting. The generated scoring function f score t is immediately executed to compute a score s for each element e in the pre-processed DOM tree. The system then selects the Top-N highestscoring elements, where N defaults to 20. The impact of varying N from 1 to 20 on pruning efficiency is visualized and analyzed in the Experiments section.
# 4. **Advantages:** [4] Discussion. The primary advantage of DOM Tree Pruning Programming lies in its combination of flexibility and structure. The LLM provides high-level, context-aware intelligence by generating keywords and weights, while the hardcoded function template ensures robust, efficient, and interpretable scoring and execution. By generating a lightweight function instead of directly processing lengthy raw HTML, this paradigm avoids attention dilution from long contexts and significantly reduces inference latency.
# 5. **Comparison to Existing Paradigms:** [5] Compared to existing multi-modal web agent paradigms, we propose a programmatic pruning strategy that efficiently removes redundant DOMelements. Our Prune4Web approach relaxes the token limits of LLMs and increases accuracy on low-level sub-task grounding from 46.80% to 88.28%.

# %% [markdown]
# [Manuel Velarde](mailto:manuel@velarde.me)
